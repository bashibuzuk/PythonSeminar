# %%
import pandas as pd

# %%
df = pd.read_csv('laptop_price.csv', encoding = 'windows-1251', index_col = 'laptop_ID')
df.head(5)
# Out:
#           Company      Product   TypeName  Inches  \
# laptop_ID
# 1           Apple  MacBook Pro  Ultrabook    13.3
# 2           Apple  Macbook Air  Ultrabook    13.3
# 3              HP       250 G6   Notebook    15.6
# 4           Apple  MacBook Pro  Ultrabook    15.4
# 5           Apple  MacBook Pro  Ultrabook    13.3
#
#                              ScreenResolution                         Cpu  \
# laptop_ID
# 1          IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 2                                    1440x900        Intel Core i5 1.8GHz
# 3                           Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
# 4          IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz
# 5          IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz
#
#             Ram               Memory                           Gpu  OpSys  \
# laptop_ID
# 1           8GB            128GB SSD  Intel Iris Plus Graphics 640  macOS
# ...

# %%
df.sample(5)
# Out:
#           Company        Product  TypeName  Inches   ScreenResolution  \
# laptop_ID
# 853          Dell    Vostro 3568  Notebook    15.6           1366x768
# 250          Dell  Inspiron 5570  Notebook    15.6  Full HD 1920x1080
# 555            HP         250 G6  Notebook    15.6  Full HD 1920x1080
# 566          Dell    Vostro 3568  Notebook    15.6           1366x768
# 1117         Acer  Chromebook 15  Notebook    15.6           1366x768
#
#                                             Cpu  Ram                Memory  \
# laptop_ID
# 853                  Intel Core i5 7200U 2.5GHz  8GB             128GB SSD
# 250                  Intel Core i7 8550U 1.8GHz  8GB  128GB SSD +  2TB HDD
# 555                    Intel Core i3 6006U 2GHz  4GB             500GB HDD
# 566                    Intel Core i3 6006U 2GHz  4GB               1TB HDD
# 1117       Intel Celeron Dual Core 3205U 1.5GHz  4GB              16GB SSD
#
#                              Gpu       OpSys  Weight  Price_euros
# ...

# %% [markdown]
# ### Задание 2
# - узнгать тип данных
# - посчитать количество нулевых значений
# - получить информацию по dataframe
# - получить статистические данные

# %%
df.dtypes
# Out:
# Company              object
# Product              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price_euros         float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1303 entries, 1 to 1320
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price_euros       1303 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 132.3+ KB

# %%
df.describe()
# Out:
#             Inches  Price_euros
# count  1303.000000  1303.000000
# mean     15.017191  1123.686992
# std       1.426304   699.009043
# min      10.100000   174.000000
# 25%      14.000000   599.000000
# 50%      15.600000   977.000000
# 75%      15.600000  1487.880000
# max      18.400000  6099.000000

# %%
df.describe(include = ['object'])
# Out:
#        Company Product  TypeName   ScreenResolution  \
# count     1303    1303      1303               1303
# unique      19     618         6                 40
# top       Dell  XPS 13  Notebook  Full HD 1920x1080
# freq       297      30       727                507
#
#                                Cpu   Ram     Memory                    Gpu  \
# count                         1303  1303       1303                   1303
# unique                         118     9         39                    110
# top     Intel Core i5 7200U 2.5GHz   8GB  256GB SSD  Intel HD Graphics 620
# freq                           190   619        412                    281
#
#              OpSys Weight
# count         1303   1303
# unique           9    179
# top     Windows 10  2.2kg
# freq          1072    121

# %% [markdown]
# ### задание 3

# %% [markdown]
# #### 3.1 ноутбуков от какой компании больше всего

# %%
df1 = df['Company'].value_counts()
df1
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
df1[df1 == df1.max()]
# Out:
# Dell      297
# Lenovo    297
# Name: Company, dtype: int64

# %% [markdown]
# #### 3.2 Какая максимальная и минимальная стоимость ноутбуков

# %%
df['Price_euros'].max(), df['Price_euros'].min()
# Out:
# (6099.0, 174.0)

# %% [markdown]
# #### 3.3 Какой самый дорогой ноутбук в данныхю Вывести характеристики только по этому ноутбуку

# %%
df[df['Price_euros'] == df['Price_euros'].max()]
# Out:
#           Company    Product TypeName  Inches  \
# laptop_ID
# 200         Razer  Blade Pro   Gaming    17.3
#
#                               ScreenResolution                          Cpu  \
# laptop_ID
# 200        4K Ultra HD / Touchscreen 3840x2160  Intel Core i7 7820HK 2.9GHz
#
#             Ram   Memory                      Gpu       OpSys  Weight  \
# laptop_ID
# 200        32GB  1TB SSD  Nvidia GeForce GTX 1080  Windows 10  3.49kg
#
#            Price_euros
# laptop_ID
# 200             6099.0

# %% [markdown]
# #### 4.1  Найти ноутбуки с самой маленькой диагональю
#  Вывести только: Компания; Тип ноутбука; Диагональ; Стоимость

# %%
df.head()
df[df['Inches'] == df['Inches'].min()][['Company','TypeName', 'Price_euros', 'Inches']]
# Out:
#           Company            TypeName  Price_euros  Inches
# laptop_ID
# 51         Lenovo  2 in 1 Convertible       319.00    10.1
# 1097       Lenovo  2 in 1 Convertible       646.27    10.1
# 1129       Lenovo  2 in 1 Convertible       549.00    10.1
# 1141       Lenovo  2 in 1 Convertible       479.00    10.1

# %% [markdown]
# #### 4.2 Сколько самый дорогой ноутбук у HP

# %%
df[df['Company'] == 'HP']['Price_euros'].max()
# Out:
# 4389.0

# %%
df.loc[df['Company'] == 'HP', 'Price_euros'].max()
# Out:
# 4389.0

# %% [markdown]
# #### 4.3 Как много ноутбуков UltraBook с 8GB RAM

# %%
df2 = df[df['TypeName'] == 'Ultrabook']
df_ultra_cunt = df2.shape[0]
df_ultra_cunt
# Out:
# 196

# %%
df2.sample(5)
# Out:
#            Company          Product   TypeName  Inches  \
# laptop_ID
# 1051       Toshiba  Tecra Z40-C-136  Ultrabook    14.0
# 5            Apple      MacBook Pro  Ultrabook    13.3
# 355           Dell    Inspiron 5570  Ultrabook    15.6
# 2            Apple      Macbook Air  Ultrabook    13.3
# 1084         Apple      MacBook 12"  Ultrabook    12.0
#
#                              ScreenResolution                         Cpu  \
# laptop_ID
# 1051              IPS Panel Full HD 1920x1080  Intel Core i7 6600U 2.6GHz
# 5          IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz
# 355                         Full HD 1920x1080  Intel Core i5 8250U 1.6GHz
# 2                                    1440x900        Intel Core i5 1.8GHz
# 1084       IPS Panel Retina Display 2304x1440         Intel Core M 1.1GHz
#
#            Ram               Memory                           Gpu       OpSys  \
# laptop_ID
# ...

# %%
df2_8GB = df2[df2['Ram'] == '8GB']
round(df2_8GB.shape[0]/df_ultra_cunt, 2)
# Out:
# 0.71

# %%
df2.value_counts('Ram', normalize=True).loc['8GB'].round(4)*100
# Out:
# 71.43

# %% [markdown]
# ### 5.1 найти все ноутбуки с ОЗУ 8 или 16; Windows 10; цена ниже 500 евро

# %%
df[((df['Ram'] == '8GB') | (df['Ram'] == '16GB')) & (df['Price_euros'] <= 500) & (df['OpSys'] == 'Windows 10')]
# Out:
#           Company                                   Product  TypeName  Inches  \
# laptop_ID
# 76           Acer                             Aspire E5-475  Notebook    14.0
# 179          Dell                             Inspiron 3567  Notebook    15.6
# 261            HP        15-BW094nd (A6-9220/8GB/128GB/W10)  Notebook    15.6
# 297            HP         17-BS037cl (i3-6006U/8GB/1TB/W10)  Notebook    17.3
# 318          Acer  ES1-523-84K7 (A8-7410/8GB/256GB/FHD/W10)  Notebook    15.6
# 371            HP            15-AY023na (N3710/8GB/2TB/W10)  Notebook    15.6
# 578            HP            14-am079na (N3710/8GB/2TB/W10)  Notebook    14.0
# 602        Lenovo                         IdeaPad 110-15ISK  Notebook    15.6
# 642          Asus         X541NA-GO414T (N3350/8GB/1TB/W10)  Notebook    15.6
# 710        Lenovo                         IdeaPad 320-15ABR  Notebook    15.6
# 1071         Acer                            Aspire ES1-523  Notebook    15.6
# ...

# %% [markdown]
# ### 5.2 Найти ноут от MSI с видеокартой GeForce GTX 1050, с диагональю не 15.6

# %%
df[(~(df['Inches'] == 15.6)) & (df['Gpu'] == 'Nvidia GeForce GTX 1050') & (df['Company'] == 'MSI')]
# Out:
#           Company     Product TypeName  Inches   ScreenResolution  \
# laptop_ID
# 75            MSI  GL72M 7RDX   Gaming    17.3  Full HD 1920x1080
# 1046          MSI  GL72M 7RDX   Gaming    17.3  Full HD 1920x1080
#
#                                    Cpu  Ram                Memory  \
# laptop_ID
# 75         Intel Core i5 7300HQ 2.5GHz  8GB  128GB SSD +  1TB HDD
# 1046       Intel Core i7 7700HQ 2.8GHz  8GB  128GB SSD +  1TB HDD
#
#                                Gpu       OpSys Weight  Price_euros
# laptop_ID
# 75         Nvidia GeForce GTX 1050  Windows 10  2.7kg       1095.0
# 1046       Nvidia GeForce GTX 1050  Windows 10  2.7kg       1191.8

# %% [markdown]
# ### 5.3 В среднем, что дешевле: Core I7 7780HQ или 7600U

# %%
df[(df['Cpu'] == 'Intel Core i7 7700HQ 2.8GHz')]['Price_euros'].mean(),df[(df['Cpu'] == 'Intel Core i7 7600U 2.8GHz')]['Price_euros'].mean()
# Out:
# (1760.4084246575342, 1915.710769230769)

# %% [markdown]
# #### 6 Найти самый легкий ноут. При это учесть , что в колонке тип str

# %%
df['Weight'].min()
# Out:
# 0.69
